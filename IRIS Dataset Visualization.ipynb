# %%
import pandas as pd
import numpy as np

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv(r'D:\7.30 PM DATA SCIENCE AND AI\DAILY SESSION MATERIALS\SEPT\7th\IRIS DATASET _ ADVANCE VISUALIZATION _ EDA 2\Iris.csv')

# %%
df
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
df.shape
# Out:
# (150, 6)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             150 non-null    int64
#  1   SepalLengthCm  150 non-null    float64
#  2   SepalWidthCm   150 non-null    float64
#  3   PetalLengthCm  150 non-null    float64
#  4   PetalWidthCm   150 non-null    float64
#  5   Species        150 non-null    object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 7.2+ KB

# %%
df.isnull().any()
# Out:
# Id               False
# SepalLengthCm    False
# SepalWidthCm     False
# PetalLengthCm    False
# PetalWidthCm     False
# Species          False
# dtype: bool

# %%
df.drop('Id', axis=1, inplace=True)

# %%
df.head()
# Out:
#    SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0            5.1           3.5            1.4           0.2  Iris-setosa
# 1            4.9           3.0            1.4           0.2  Iris-setosa
# 2            4.7           3.2            1.3           0.2  Iris-setosa
# 3            4.6           3.1            1.5           0.2  Iris-setosa
# 4            5.0           3.6            1.4           0.2  Iris-setosa

# %%
df['Species'].unique()
# Out:
# array(['Iris-setosa', 'Iris-versicolor', 'Iris-virginica'], dtype=object)

# %%
df['Species'].value_counts()
# Out:
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# Name: Species, dtype: int64

# %% [markdown]
# ### Visualizations

# %% [markdown]
# ### 1. Countplot

# %%
v1 = sns.countplot('Species', data=df)

# %% [markdown]
# ### 2. Jointplot

# %%
v2 = sns.jointplot('SepalLengthCm','SepalWidthCm', data=df)

# %%
v3 = sns.jointplot('SepalLengthCm', 'SepalWidthCm', kind='reg', data=df)

# %%
v4 = sns.jointplot('SepalLengthCm', 'SepalWidthCm', kind='kde', data=df)

# %%
v5 = sns.jointplot('SepalLengthCm', 'SepalWidthCm', kind='hex', data=df)

# %% [markdown]
# ### 3. FacetGrid

# %%
f = sns.FacetGrid(df, hue='Species', size=5)

# %%
f = f.map(plt.scatter, 'SepalLengthCm', 'SepalWidthCm')
f.add_legend()

# %% [markdown]
# ### 4. Boxplot

# %%
df.head()
# Out:
#    SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0            5.1           3.5            1.4           0.2  Iris-setosa
# 1            4.9           3.0            1.4           0.2  Iris-setosa
# 2            4.7           3.2            1.3           0.2  Iris-setosa
# 3            4.6           3.1            1.5           0.2  Iris-setosa
# 4            5.0           3.6            1.4           0.2  Iris-setosa

# %%
plt.figure(figsize=(8,6))
box1 = sns.boxplot(data=df, x='Species', y='PetalLengthCm')

# %%
plt.figure(figsize=(8,6))
box2 = sns.boxplot(data=df, x='Species', y='PetalLengthCm', order=['Iris-virginica','Iris-versicolor','Iris-setosa'])

# %%
plt.figure(figsize=(8,6))
box3 = sns.boxplot(data=df, x='Species', y='PetalWidthCm')

# %%
box3 = df.boxplot(by='Species', figsize=(12,10))

# %% [markdown]
# ### 5. Stripplot

# %%
plt.figure(figsize=(8,6))
stp = sns.stripplot(data=df, x='Species',y='SepalLengthCm', size=6)

# %%
plt.figure(figsize=(8,6))
stp1 = sns.stripplot(data=df, x='Species',y='SepalWidthCm', size=6)

# %% [markdown]
# ### 6. Comination of Boxplot and Stripplot

# %%
plt.figure(figsize=(8,6))
v3 = sns.boxplot(data=df, x='Species',y='SepalLengthCm')
v3 = sns.stripplot(data=df, x='Species',y='SepalLengthCm', palette='summer')

# %% [markdown]
# ### 7. ViolinPlot

# %%
plt.figure(figsize=(8,6))
vp = sns.violinplot(data=df, x='Species',y='SepalLengthCm')

# %%
plt.figure(figsize=(8,6))
vp1 = sns.violinplot(data=df, x='Species',y='SepalWidthCm')

# %%
sns.set_style('darkgrid')

f, axes = plt.subplots(2,2, figsize=(14,10))
v11 = sns.violinplot(data=df, x='Species',y='SepalLengthCm', ax=axes[0,0])
v12 = sns.violinplot(data=df, x='Species',y='SepalWidthCm', ax=axes[0,1])
v13 = sns.violinplot(data=df, x='Species',y='PetalLengthCm', ax=axes[1,0])
v14 = sns.violinplot(data=df, x='Species',y='PetalWidthCm', ax=axes[1,1])

# %% [markdown]
# ### 8. Pairplot

# %%
sns.pairplot(data=df, kind='scatter')

# %%
sns.pairplot(data=df, kind='reg')

# %%
sns.pairplot(data=df, hue='Species')

# %% [markdown]
# ### 9. Heatmap

# %%
plt.figure(figsize=(10,8))
plt.title('HeatMap of IRIS Flower Dataset')
correlation = df.corr()
hm = sns.heatmap(correlation, annot=True, cmap='cubehelix', square=True, linewidths=1, linecolor='k')
hm.set_xticklabels(hm.get_xticklabels(), size=10)
hm.set_yticklabels(hm.get_yticklabels(), size=10)
plt.show()

# %% [markdown]
# ### 10. Distribution Plot

# %%
df.hist(edgecolor='black', linewidth=1.1)
f = plt.gcf()
f.set_size_inches(10,8)

# %% [markdown]
# ### 11. Swarm Plot

# %%
sns.set_style('whitegrid')
plt.figure(figsize=(8,6))
sp = sns.swarmplot(data=df, x='Species', y='PetalLengthCm')

# %%
plt.figure(figsize=(8,6))
sp1 = sns.swarmplot(data=df, x='Species', y='PetalWidthCm')

# %% [markdown]
# ### 12. Combination of Violinplot and Swarmplot

# %%
plt.figure(figsize=(8,6))
sp0 = sns.violinplot(data=df, x='Species', y='PetalWidthCm')
sp0 = sns.swarmplot(data=df, x='Species', y='PetalWidthCm', color='white')

# %% [markdown]
# ### 13. LMplot

# %%
plt.figure(figsize=(8,6))
lm0 = sns.lmplot(data=df, x='PetalLengthCm', y='PetalWidthCm')

# %%
plt.figure(figsize=(8,6))
lm1 = sns.lmplot(data=df, x='SepalLengthCm', y='SepalWidthCm')

# %% [markdown]
# ### 14. Factorplot

# %%
plt.figure(figsize=(8,6))
fac = sns.factorplot(data=df, x='Species', y='PetalLengthCm')

# %%
plt.figure(figsize=(8,6))
fac0 = sns.factorplot(data=df, x='Species', y='SepalLengthCm', color='magenta')

# %%
sns.factorplot(data=df, x='Species', y='PetalLengthCm')
sns.factorplot(data=df, x='Species', y='SepalLengthCm', color='magenta')

# %% [markdown]
# ### 15. Boxenplot

# %%
plt.figure(figsize=(8,6))
bxep = sns.boxenplot(data=df, x='Species', y='PetalLengthCm')

# %%
plt.figure(figsize=(8,6))
bxep1 = sns.boxenplot(data=df, x='Species', y='PetalWidthCm')

# %% [markdown]
# ### 16. KDE Plot

# %%
plt.figure(figsize=(8,6))
k0 = sns.kdeplot(df.PetalLengthCm, df.SepalLengthCm)

# %%
plt.figure(figsize=(8,6))
k1 = sns.kdeplot(df.PetalWidthCm, df.SepalWidthCm)

# %%
f, axes = plt.subplots(2,2, figsize=(12,10))

k00 = sns.kdeplot(df.PetalLengthCm, df.SepalLengthCm, ax=axes[0,0], cmap='plasma')
k01 = sns.kdeplot(df.PetalWidthCm, df.SepalWidthCm, shade=True, ax=axes[0,1], cmap='plasma')
k10 = sns.kdeplot(df.SepalLengthCm, df.SepalWidthCm, shade_lowest=True, shade=True, ax=axes[1,0], cmap='Reds')
k11 = sns.kdeplot(df.PetalLengthCm, df.PetalWidthCm, shade_lowest=True, shade=False, ax=axes[1,1], cmap='plasma')

# %% [markdown]
# ### 17. Dashboard

# %%
f, axes = plt.subplots(2,2, figsize=(12,10))

db00 = sns.stripplot(data=df, x='Species',y='SepalWidthCm', ax=axes[0,0])
db01 = sns.boxplot(data=df, x='Species', y='PetalLengthCm', ax=axes[0,1])
db10 = sns.kdeplot(df.PetalWidthCm, df.SepalWidthCm, shade=True, cmap='plasma', ax=axes[1,0])
db11 = sns.violinplot(data=df, x='Species',y='SepalLengthCm', ax=axes[1,1])

# %% [markdown]
# ### 18. Stacked Histogram

# %%
df['Species'] = df['Species'].astype('category')

# %%
df['Species'].dtypes
# Out:
# CategoricalDtype(categories=['Iris-setosa', 'Iris-versicolor', 'Iris-virginica'], ordered=False)

# %%
df.head()
# Out:
#    SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0            5.1           3.5            1.4           0.2  Iris-setosa
# 1            4.9           3.0            1.4           0.2  Iris-setosa
# 2            4.7           3.2            1.3           0.2  Iris-setosa
# 3            4.6           3.1            1.5           0.2  Iris-setosa
# 4            5.0           3.6            1.4           0.2  Iris-setosa

# %%
df['Species'].unique()
# Out:
# ['Iris-setosa', 'Iris-versicolor', 'Iris-virginica']
# Categories (3, object): ['Iris-setosa', 'Iris-versicolor', 'Iris-virginica']

# %%
plt.hist([df[df.Species == 'Iris-setosa'].SepalLengthCm, \
        df[df.Species == 'Iris-versicolor'].SepalLengthCm, \
        df[df.Species == 'Iris-virginica'].SepalLengthCm], bins=15, stacked=True)
plt.show()

# %%
list1 = list()
mylabels=list()
for gen in df.Species.cat.categories:
    list1.append(df[df.Species==gen].SepalLengthCm)
    mylabels.append(gen)

hist1 = plt.hist(list1, bins=15, stacked=True, label=mylabels)
plt.legend()
plt.show()

# %% [markdown]
# ### 19. Distplot

# %%
dp = sns.distplot(df['PetalLengthCm'], bins=15)

# %%
dp1 = sns.distplot(df['SepalLengthCm'], bins=15)

# %% [markdown]
# ### 20. Area Plot

# %%
df.plot.area(y=['SepalLengthCm','SepalWidthCm','PetalLengthCm','PetalWidthCm'], alpha=0.5 ,figsize=(12,6))
# Out:
# <AxesSubplot:>
